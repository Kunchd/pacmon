# %%
from infra import *
from eval import *
from scheds import *

# %%
run_test(scheduler=NaiveScheduler)
# Out:
# Latency 0-0: 0
# Latency 20-0: 8
# Latency 10-0: 20
# Latency 30-0: 9
# Latency 50-0: 0
# Latency 70-0: 0
# Latency 60-0: 10
# Latency 40-0: 39
# Latency 80-0: 0
# Latency 90-0: 0
# Latency 100-0: 0
# Latency 110-0: 0
# Latency 130-0: 0
# Latency 140-0: 0
# Latency 120-0: 23
# Latency 150-0: 0
# Latency 160-0: 0
# Latency 170-0: 0
# Latency 180-0: 0
# Latency 190-0: 0
# Latency 200-0: 0
# Latency 220-0: 0
# Latency 210-0: 27
# Latency 230-0: 7
# Latency 240-0: 0
# Latency 250-0: 0
# Latency 260-0: 0
# Latency 280-0: 0
# Latency 290-0: 0
# Latency 270-0: 26
# Latency 310-0: 0
# Latency 300-0: 28
# Latency 330-0: 0
# Latency 320-0: 12
# Latency 340-0: 0
# Latency 350-0: 0
# Latency 360-0: 0
# Latency 370-0: 0
# Latency 390-0: 0
# Latency 380-0: 26
# Latency 400-0: 6
# Latency 410-0: 0
# Latency 420-0: 0
# Latency 430-0: 0
# Latency 450-0: 6
# Latency 460-0: 0
# Latency 440-0: 26
# Latency 470-0: 0
# Latency 480-0: 0
# Latency 490-0: 0
# Latency 510-0: 0
# Latency 520-0: 0
# ...
